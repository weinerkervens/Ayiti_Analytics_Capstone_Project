# %% [markdown]
# # Projet final

# %% [markdown]
# Ce projet vise, à partir de quelques analyses, à construire une échelle de niveau de risque lié au COVID-19.
# A la fin de cette étude, nous espérons pouvoir classer des pays ou certaines zones d'un pays par rapport à leur position sur l'échelle de risque.

# %% [markdown]
# Le premier point sera de définir ce qu'est un pays, ou une zone à risque par rapport au COVID-19

# %% [markdown]
# ## Quels sont les caractéristiques d'une zone risquée?

# %% [markdown]
# Pour répondre à une telle question il faut au préalable connaitre les facteurs qui favorisent la propagation du coronavirus.

# %% [markdown]
# #### Quels sont les facteurs qui favorisent la propagation du coronavirus?

# %% [markdown]
# Pour pouvoir identifier ces facteurs, il faut prendre en compte les gestes barrières:
#
# - Lavez-vous les mains très régulièrement (avec de l'eau et du savon, ou du gel hydro-alcoolique)
# - Toussez ou éternuez dans votre coude ou dans un mouchoir
# - Restez toujours à plus d’un mètre les uns des autres
# - Utilisez un mouchoir à usage unique et jetez-le
# - Saluez sans vous serrer la main, arrêtez les embrassades
# - Evitez de vous toucher le visage en particulier le nez et la bouche
# - Portez un masque quand la distance d’un mètre ne peut pas être respectée

# %% [markdown]
# ---

# %%
import folium
from folium.plugins import MarkerCluster
from folium.map import Icon

# %%
latitude = 19.0000
longitude = -70.6667

map_hispaniola = folium.Map(location=[latitude, longitude], zoom_start=7, tiles='CartoDB positron')
marker_cluster = MarkerCluster().add_to(map_hispaniola)
    
map_hispaniola
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Les aéroports de l'ile

# %%
import pandas as pd
import numpy as np

# %%
ht_airports = pd.read_csv(r'../input/ht-airports.csv')
ht_airports
# Out:
#           id        ident                 type  \
# 0  #meta +id  #meta +code  #loc +airport +type
# 1       4825         MTPP       medium_airport
# 2       4823         MTCH       medium_airport
# 3       4824         MTJA       medium_airport
# 4      32146         MTPX       medium_airport
# 5       4822         MTCA       medium_airport
# 6      31696         MTJE       medium_airport
# 7      42314      HT-0001        small_airport
# 8      46449      HT-0002        small_airport
#
#                                          name        latitude_deg  \
# 0                         #loc +airport +name           #geo +lat
# 1  Toussaint Louverture International Airport  18.579999923706055
# 2           Cap Haitien International Airport              19.733
# 3                              Jacmel Airport  18.241100311279297
# 4                        Port-de-Paix Airport    19.9335994720459
# 5                           Les Cayes Airport  18.271099090576172
# ...

# %%
ht_airports = ht_airports.iloc[1:,:]
ht_airports
# Out:
#       id    ident            type                                        name  \
# 1   4825     MTPP  medium_airport  Toussaint Louverture International Airport
# 2   4823     MTCH  medium_airport           Cap Haitien International Airport
# 3   4824     MTJA  medium_airport                              Jacmel Airport
# 4  32146     MTPX  medium_airport                        Port-de-Paix Airport
# 5   4822     MTCA  medium_airport                           Les Cayes Airport
# 6  31696     MTJE  medium_airport                             Jérémie Airport
# 7  42314  HT-0001   small_airport                               Bowen Airport
# 8  46449  HT-0002   small_airport                       Anse-a-Galets Airport
#
#          latitude_deg       longitude_deg elevation_ft continent iso_country  \
# 1  18.579999923706055   -72.2925033569336          122       NaN          HT
# 2              19.733          -72.194702           10       NaN          HT
# ...

# %%
ht_airports.reset_index(drop=True,inplace=True)
ht_airports
# Out:
#       id    ident            type                                        name  \
# 0   4825     MTPP  medium_airport  Toussaint Louverture International Airport
# 1   4823     MTCH  medium_airport           Cap Haitien International Airport
# 2   4824     MTJA  medium_airport                              Jacmel Airport
# 3  32146     MTPX  medium_airport                        Port-de-Paix Airport
# 4   4822     MTCA  medium_airport                           Les Cayes Airport
# 5  31696     MTJE  medium_airport                             Jérémie Airport
# 6  42314  HT-0001   small_airport                               Bowen Airport
# 7  46449  HT-0002   small_airport                       Anse-a-Galets Airport
#
#          latitude_deg       longitude_deg elevation_ft continent iso_country  \
# 0  18.579999923706055   -72.2925033569336          122       NaN          HT
# 1              19.733          -72.194702           10       NaN          HT
# ...

# %%
ht_airports.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'gps_code', 'iata_code',
#        'local_code', 'home_link', 'wikipedia_link', 'keywords', 'score',
#        'last_updated'],
#       dtype='object')

# %%
ht_airports = ht_airports[['name','municipality', 'type','latitude_deg', 'longitude_deg', 'iso_country', 'iso_region', 'score']]
ht_airports
# Out:
#                                          name    municipality            type  \
# 0  Toussaint Louverture International Airport  Port-au-Prince  medium_airport
# 1           Cap Haitien International Airport     Cap Haitien  medium_airport
# 2                              Jacmel Airport          Jacmel  medium_airport
# 3                        Port-de-Paix Airport    Port-de-Paix  medium_airport
# 4                           Les Cayes Airport       Les Cayes  medium_airport
# 5                             Jérémie Airport         Jeremie  medium_airport
# 6                               Bowen Airport  Port-au-Prince   small_airport
# 7                       Anse-a-Galets Airport             NaN   small_airport
#
#          latitude_deg       longitude_deg iso_country iso_region score
# 0  18.579999923706055   -72.2925033569336          HT      HT-OU   975
# 1              19.733          -72.194702          HT      HT-ND   800
# ...

# %%
ht_airports.fillna('Anse-a-Galets',inplace=True)
# Out:
# C:\Users\bootcamp\Anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
ht_airports
# Out:
#                                          name    municipality            type  \
# 0  Toussaint Louverture International Airport  Port-au-Prince  medium_airport
# 1           Cap Haitien International Airport     Cap Haitien  medium_airport
# 2                              Jacmel Airport          Jacmel  medium_airport
# 3                        Port-de-Paix Airport    Port-de-Paix  medium_airport
# 4                           Les Cayes Airport       Les Cayes  medium_airport
# 5                             Jérémie Airport         Jeremie  medium_airport
# 6                               Bowen Airport  Port-au-Prince   small_airport
# 7                       Anse-a-Galets Airport   Anse-a-Galets   small_airport
#
#          latitude_deg       longitude_deg iso_country iso_region score
# 0  18.579999923706055   -72.2925033569336          HT      HT-OU   975
# 1              19.733          -72.194702          HT      HT-ND   800
# ...

# %%
ht_airports.dtypes
# Out:
# name             object
# municipality     object
# type             object
# latitude_deg     object
# longitude_deg    object
# iso_country      object
# iso_region       object
# score            object
# dtype: object

# %%
ht_airports[['latitude_deg','longitude_deg']] = ht_airports[['latitude_deg','longitude_deg']].astype('float')
# Out:
# C:\Users\bootcamp\Anaconda3\lib\site-packages\pandas\core\frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
ht_airports.dtypes
# Out:
# name              object
# municipality      object
# type              object
# latitude_deg     float64
# longitude_deg    float64
# iso_country       object
# iso_region        object
# score             object
# dtype: object

# %%
ht_airports
# Out:
#                                          name    municipality            type  \
# 0  Toussaint Louverture International Airport  Port-au-Prince  medium_airport
# 1           Cap Haitien International Airport     Cap Haitien  medium_airport
# 2                              Jacmel Airport          Jacmel  medium_airport
# 3                        Port-de-Paix Airport    Port-de-Paix  medium_airport
# 4                           Les Cayes Airport       Les Cayes  medium_airport
# 5                             Jérémie Airport         Jeremie  medium_airport
# 6                               Bowen Airport  Port-au-Prince   small_airport
# 7                       Anse-a-Galets Airport   Anse-a-Galets   small_airport
#
#    latitude_deg  longitude_deg iso_country iso_region score
# 0     18.580000     -72.292503          HT      HT-OU   975
# 1     19.733000     -72.194702          HT      HT-ND   800
# 2     18.241100     -72.518501          HT      HT-SE   250
# ...

# %%
ht_airports['score'] = ht_airports['score'].astype('int')
# Out:
# C:\Users\bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ht_airports.dtypes
# Out:
# name              object
# municipality      object
# type              object
# latitude_deg     float64
# longitude_deg    float64
# iso_country       object
# iso_region        object
# score              int32
# dtype: object

# %%
ht_airports
# Out:
#                                          name    municipality            type  \
# 0  Toussaint Louverture International Airport  Port-au-Prince  medium_airport
# 1           Cap Haitien International Airport     Cap Haitien  medium_airport
# 2                              Jacmel Airport          Jacmel  medium_airport
# 3                        Port-de-Paix Airport    Port-de-Paix  medium_airport
# 4                           Les Cayes Airport       Les Cayes  medium_airport
# 5                             Jérémie Airport         Jeremie  medium_airport
# 6                               Bowen Airport  Port-au-Prince   small_airport
# 7                       Anse-a-Galets Airport   Anse-a-Galets   small_airport
#
#    latitude_deg  longitude_deg iso_country iso_region  score
# 0     18.580000     -72.292503          HT      HT-OU    975
# 1     19.733000     -72.194702          HT      HT-ND    800
# 2     18.241100     -72.518501          HT      HT-SE    250
# ...

# %%
ht_airports.to_csv(r'../output/ht_airports.csv',index=False)

# %% [markdown]
# ---

# %%
do_airports = pd.read_csv(r'../input/do-airports.csv')
do_airports.head()
# Out:
#           id        ident                 type  \
# 0  #meta +id  #meta +code  #loc +airport +type
# 1       4636         MDPC        large_airport
# 2       4638         MDSD        large_airport
# 3       4637         MDPP       medium_airport
# 4       4635         MDLR       medium_airport
#
#                                      name        latitude_deg  \
# 0                     #loc +airport +name           #geo +lat
# 1        Punta Cana International Airport  18.567399978599997
# 2      Las Américas International Airport      18.42970085144
# 3  Gregorio Luperon International Airport   19.75790023803711
# 4     Casa De Campo International Airport  18.450700759887695
#
#         longitude_deg         elevation_ft                 continent  \
# 0           #geo +lon  #geo +elevation +ft  #region +continent +code
# 1  -68.36340332030001                   47                       NaN
# 2    -69.668899536133                   59                       NaN
# ...

# %%
do_airports = do_airports.iloc[1:,:]
do_airports
# Out:
#         id    ident            type  \
# 1     4636     MDPC   large_airport
# 2     4638     MDSD   large_airport
# 3     4637     MDPP  medium_airport
# 4     4635     MDLR  medium_airport
# 5     4640     MDST  medium_airport
# 6    30673     MDCY  medium_airport
# 7    30382     MDPO   small_airport
# 8     4634     MDJB  medium_airport
# 9     4631     MDAB   small_airport
# 10   42308     MDBL   small_airport
# 11   30384     MDHE          closed
# 12    4632     MDBH  medium_airport
# 13    4633     MDCR  medium_airport
# 14   42302     MDAD   small_airport
# 15   42304     MDBA   small_airport
# 16   29799     MDCZ   small_airport
# 17   42303     MDAN   small_airport
# 18   29814     MDDJ   small_airport
# 19   42307     MDBG   small_airport
# 20   42306     MDBE   small_airport
# 21   42305     MDBC   small_airport
# 22   30156     MDMC   small_airport
# 23   42311     MDSB          closed
# 24    4639     MDSI  medium_airport
# 25   42312     MDSJ          closed
# ...

# %%
do_airports.reset_index(drop=True,inplace=True)
do_airports
# Out:
#         id    ident            type  \
# 0     4636     MDPC   large_airport
# 1     4638     MDSD   large_airport
# 2     4637     MDPP  medium_airport
# 3     4635     MDLR  medium_airport
# 4     4640     MDST  medium_airport
# 5    30673     MDCY  medium_airport
# 6    30382     MDPO   small_airport
# 7     4634     MDJB  medium_airport
# 8     4631     MDAB   small_airport
# 9    42308     MDBL   small_airport
# 10   30384     MDHE          closed
# 11    4632     MDBH  medium_airport
# 12    4633     MDCR  medium_airport
# 13   42302     MDAD   small_airport
# 14   42304     MDBA   small_airport
# 15   29799     MDCZ   small_airport
# 16   42303     MDAN   small_airport
# 17   29814     MDDJ   small_airport
# 18   42307     MDBG   small_airport
# 19   42306     MDBE   small_airport
# 20   42305     MDBC   small_airport
# 21   30156     MDMC   small_airport
# 22   42311     MDSB          closed
# 23    4639     MDSI  medium_airport
# 24   42312     MDSJ          closed
# ...

# %%
do_airports = do_airports[['name','municipality', 'type','latitude_deg', 'longitude_deg', 'iso_country', 'iso_region', 'score']]
do_airports
# Out:
#                                                  name            municipality  \
# 0                    Punta Cana International Airport              Punta Cana
# 1                  Las Américas International Airport           Santo Domingo
# 2              Gregorio Luperon International Airport            Puerto Plata
# 3                 Casa De Campo International Airport               La Romana
# 4                         Cibao International Airport                Santiago
# 5               Samaná El Catey International Airport                  Samana
# 6                          Samana El Portillo Airport                  Samana
# 7                    La Isabela International Airport              La Isabela
# 8                               Arroyo Barril Airport           Arroyo Barril
# 9                                  Boca Chica Airport              Boca Chica
# 10                                    Herrera Airport           Santo Domingo
# ...

# %%
do_airports[['latitude_deg','longitude_deg']] = do_airports[['latitude_deg','longitude_deg']].astype('float')
do_airports['score'] = do_airports['score'].astype('int')
do_airports
# Out:
# C:\Users\bootcamp\Anaconda3\lib\site-packages\pandas\core\frame.py:3494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                  name            municipality  \
# 0                    Punta Cana International Airport              Punta Cana
# ...

# %%
do_airports.dtypes
# Out:
# name              object
# municipality      object
# type              object
# latitude_deg     float64
# longitude_deg    float64
# iso_country       object
# iso_region        object
# score              int32
# dtype: object

# %%
do_airports.to_csv(r'../output/do_airports.csv', index = False)

# %% [markdown]
# ---

# %%
excel_sheets = pd.read_excel(r'../input/hti_adminboundaries_tabulardata.xlsx', sheet_name = None)
type(excel_sheets)
# Out:
# collections.OrderedDict

# %%
excel_sheets.keys()
# Out:
# odict_keys(['hti_pop2019_adm0', 'hti_pop2019_adm1', 'hti_pop2019_adm2', 'hti_pop2019_adm3'])

# %%
excel_sheets['hti_pop2019_adm0']
# Out:
#   adm0code adm0_en adm0_fr adm0_ht  IHSI_UNFPA_2019  IHSI_UNFPA_2019_female  \
# 0       HT   Haiti   Haïti   Ayiti     1.289340e+07                 6511669
#
#    IHSI_UNFPA_2019_male
# 0               6381732

# %%
admins_pop = excel_sheets['hti_pop2019_adm1'][['adm0code','adm0_en', 'adm1_en', 'adm1_fr', 'IHSI_UNFPA_2019']]
admins_pop.head()
# Out:
#   adm0code adm0_en     adm1_en     adm1_fr  IHSI_UNFPA_2019
# 0       HT   Haiti        West       Ouest     5.010206e+06
# 1       HT   Haiti  South-East     Sud-Est     8.939007e+05
# 2       HT   Haiti       North        Nord     1.159762e+06
# 3       HT   Haiti  North-East    Nord-Est     4.444631e+05
# 4       HT   Haiti  Artibonite  Artibonite     2.047153e+06

# %%
admins_pop.dtypes
# Out:
# adm0code            object
# adm0_en             object
# adm1_en             object
# adm1_fr             object
# IHSI_UNFPA_2019    float64
# dtype: object

# %%
admins_pop.shape
# Out:
# (10, 5)

# %%
admins_pop['IHSI_UNFPA_2019'] = admins_pop['IHSI_UNFPA_2019'].astype('int')
admins_pop
# Out:
# C:\Users\bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#   adm0code adm0_en      adm1_en      adm1_fr  IHSI_UNFPA_2019
# 0       HT   Haiti         West        Ouest          5010205
# 1       HT   Haiti   South-East      Sud-Est           893900
# 2       HT   Haiti        North         Nord          1159761
# 3       HT   Haiti   North-East     Nord-Est           444463
# 4       HT   Haiti   Artibonite   Artibonite          2047152
# 5       HT   Haiti       Centre       Centre           845594
# 6       HT   Haiti        South          Sud           791084
# 7       HT   Haiti  Grande'Anse  Grande'Anse           481065
# ...

# %%
admins_pop.to_csv(r'../output/ht_pop_by_dep.csv', index = False)

# %% [markdown]
# ---

# %%
import wikipedia as wp

# %%
wp.set_lang('fr')
html1 = wp.page(r"Départements d'Haïti — Wikipédia").html()
df = pd.read_html(html1, header = 0)[0]

# %%
df
# Out:
#    Code ihsi[2]            Département Chef-Lieu ou Capitale Superficie (km²)  \
# 0             5             Artibonite          Les Gonaïves            4 984
# 1             6                 Centre                Hinche            3 675
# 2             8             Grand'Anse               Jérémie            1 871
# 3            10  Nippes (créé en 2003)             Miragoâne            1 268
# 4             3                   Nord           Cap-Haïtien            2 106
# 5             4               Nord-Est          Fort-Liberté            1 805
# 6             9             Nord-Ouest          Port-de-Paix            2 176
# 7             1                  Ouest        Port-au-Prince            4 827
# 8             7                    Sud             Les Cayes            2 794
# 9             2                Sud-Est                Jacmel            2 023
#
#   Population estimée (2015)[3]  Densité/km²  \
# 0                    1 727 524         3466
# ...

# %%
df['Département'] = df['Département'].replace({'Nippes (créé en 2003)':'Nippes', "Grand'Anse":"Grande'Anse"})

# %%
df
# Out:
#    Code ihsi[2]  Département Chef-Lieu ou Capitale Superficie (km²)  \
# 0             5   Artibonite          Les Gonaïves            4 984
# 1             6       Centre                Hinche            3 675
# 2             8  Grande'Anse               Jérémie            1 871
# 3            10       Nippes             Miragoâne            1 268
# 4             3         Nord           Cap-Haïtien            2 106
# 5             4     Nord-Est          Fort-Liberté            1 805
# 6             9   Nord-Ouest          Port-de-Paix            2 176
# 7             1        Ouest        Port-au-Prince            4 827
# 8             7          Sud             Les Cayes            2 794
# 9             2      Sud-Est                Jacmel            2 023
#
#   Population estimée (2015)[3]  Densité/km²  \
# 0                    1 727 524         3466
# 1                      746 236          203
# 2                      468 301         2503
# ...

# %%
df = df[['Département', 'Chef-Lieu ou Capitale', r'Superficie (km²)']]
df
# Out:
#    Département Chef-Lieu ou Capitale Superficie (km²)
# 0   Artibonite          Les Gonaïves            4 984
# 1       Centre                Hinche            3 675
# 2  Grande'Anse               Jérémie            1 871
# 3       Nippes             Miragoâne            1 268
# 4         Nord           Cap-Haïtien            2 106
# 5     Nord-Est          Fort-Liberté            1 805
# 6   Nord-Ouest          Port-de-Paix            2 176
# 7        Ouest        Port-au-Prince            4 827
# 8          Sud             Les Cayes            2 794
# 9      Sud-Est                Jacmel            2 023

# %%
df.dtypes
# Out:
# Département              object
# Chef-Lieu ou Capitale    object
# Superficie (km²)         object
# dtype: object

# %% [markdown]
# df[r'Superficie (km²)'] = pd.to_numeric(df[r'Superficie (km²)'],errors='coerce')

# %% [markdown]
# df[r'Superficie (km²)'] = df[r'Superficie (km²)'].str.split()#.astype('int')
# df

# %%
df['a'] = df[r'Superficie (km²)'].str.split().apply(lambda x: int(x[0]))
df['b'] = df[r'Superficie (km²)'].str.split().apply(lambda x: int(x[1]))
df[r'Superficie (km²)'] = df.a*1000 + df.b
df = df[['Département', 'Chef-Lieu ou Capitale', r'Superficie (km²)']]
# Out:
# C:\Users\bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\bootcamp\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#    Département Chef-Lieu ou Capitale  Superficie (km²)
# 0   Artibonite          Les Gonaïves              4984
# 1       Centre                Hinche              3675
# 2  Grande'Anse               Jérémie              1871
# 3       Nippes             Miragoâne              1268
# 4         Nord           Cap-Haïtien              2106
# 5     Nord-Est          Fort-Liberté              1805
# 6   Nord-Ouest          Port-de-Paix              2176
# 7        Ouest        Port-au-Prince              4827
# 8          Sud             Les Cayes              2794
# 9      Sud-Est                Jacmel              2023

# %%
df.dtypes
# Out:
# Département              object
# Chef-Lieu ou Capitale    object
# Superficie (km²)          int64
# dtype: object

# %%
df.to_csv(r'../output/ht_dep_sup.csv', index = False)
