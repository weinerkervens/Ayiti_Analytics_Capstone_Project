# %% [markdown]
# ---

# %% [markdown]
# ### Imports section

# %%
# Let's import useful packages for this notebook

import pandas as pd
import wikipedia as wp
from geopy.geocoders import Nominatim
import time

# Import packages to make api calls
import requests
import json


# Packages for data viz
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Define a style  
mpl.style.use('seaborn-whitegrid')

# %%
# Create an instance of Nominatim
geolocator = Nominatim(user_agent="my_app")

# %% [markdown]
# ---

# %% [markdown]
# ### Functions section

# %%
# Function to check the difference of two (2) pandas series
def is_diff(serie_1, serie_2):
    d1 = set(serie_1.unique().tolist())
    d2 = set(serie_2.unique().tolist())
    if not (d1.difference(d2)):
        print('Absolutely no difference')
    else:
        print(d1.difference(d2))

# %% [markdown]
# ---

# %%
# Import and display some datasets
df_1 = pd.read_csv(r'../output/Notebook 0/ht_airports.csv')
df_2 = pd.read_csv(r'../output/Notebook 0/ht_dep_sup.csv')
df_3 = pd.read_csv(r'../output/Notebook 0/ht_pop_by_dep.csv')
display(df_1.head())
display(df_2.head())
display(df_3.head())
# Out:
#                                          name    municipality            type  \
# 0  Toussaint Louverture International Airport  Port-au-Prince  medium_airport
# 1           Cap Haitien International Airport     Cap Haitien  medium_airport
# 2                              Jacmel Airport          Jacmel  medium_airport
# 3                        Port-de-Paix Airport    Port-de-Paix  medium_airport
# 4                           Les Cayes Airport       Les Cayes  medium_airport
#
#    latitude_deg  longitude_deg iso_country iso_region  score
# 0     18.580000     -72.292503          HT      HT-OU    975
# 1     19.733000     -72.194702          HT      HT-ND    800
# 2     18.241100     -72.518501          HT      HT-SE    250
# 3     19.933599     -72.848602          HT      HT-NO    450
# 4     18.271099     -73.788300          HT      HT-SD    250
#    Département Chef-Lieu ou Capitale  Superficie (km²)
# 0   Artibonite          Les Gonaïves              4984
# 1       Centre                Hinche              3675
# 2  Grande'Anse               Jérémie              1871
# 3       Nippes             Miragoâne              1268
# 4         Nord           Cap-Haïtien              2106
#   adm0code adm0_en     adm1_en     adm1_fr  IHSI_UNFPA_2019
# 0       HT   Haiti        West       Ouest          5010205
# 1       HT   Haiti  South-East     Sud-Est           893900
# 2       HT   Haiti       North        Nord          1159761
# 3       HT   Haiti  North-East    Nord-Est           444463
# 4       HT   Haiti  Artibonite  Artibonite          2047152

# %% [markdown]
# ### Displaying, renaming and merging datasets

# %%
df_2.columns
# Out:
# Index(['Département', 'Chef-Lieu ou Capitale', 'Superficie (km²)'], dtype='object')

# %%
df_3.columns
# Out:
# Index(['adm0code', 'adm0_en', 'adm1_en', 'adm1_fr', 'IHSI_UNFPA_2019'], dtype='object')

# %%
df_3.rename(columns={'adm1_fr':'Département'}, inplace = True)
df_3.head()
# Out:
#   adm0code adm0_en     adm1_en Département  IHSI_UNFPA_2019
# 0       HT   Haiti        West       Ouest          5010205
# 1       HT   Haiti  South-East     Sud-Est           893900
# 2       HT   Haiti       North        Nord          1159761
# 3       HT   Haiti  North-East    Nord-Est           444463
# 4       HT   Haiti  Artibonite  Artibonite          2047152

# %%
df_ht = df_2.merge(df_3[['Département','adm0code','IHSI_UNFPA_2019']], on='Département', how='right')
df_ht.rename(columns={'IHSI_UNFPA_2019':'Population'}, inplace = True)
df_ht.head()
# Out:
#    Département Chef-Lieu ou Capitale  Superficie (km²) adm0code  Population
# 0   Artibonite          Les Gonaïves              4984       HT     2047152
# 1       Centre                Hinche              3675       HT      845594
# 2  Grande'Anse               Jérémie              1871       HT      481065
# 3       Nippes             Miragoâne              1268       HT      351593
# 4         Nord           Cap-Haïtien              2106       HT     1159761

# %%
df_ht.dtypes
# Out:
# Département              object
# Chef-Lieu ou Capitale    object
# Superficie (km²)          int64
# adm0code                 object
# Population                int64
# dtype: object

# %% [markdown]
# ### Computing a new column for density by Department

# %%
df_ht['Density/km²'] = (df_ht.Population / df_ht['Superficie (km²)']).apply(lambda x: round(x) + 1 )
df_ht.head()
# Out:
#    Département Chef-Lieu ou Capitale  Superficie (km²) adm0code  Population  \
# 0   Artibonite          Les Gonaïves              4984       HT     2047152
# 1       Centre                Hinche              3675       HT      845594
# 2  Grande'Anse               Jérémie              1871       HT      481065
# 3       Nippes             Miragoâne              1268       HT      351593
# 4         Nord           Cap-Haïtien              2106       HT     1159761
#
#    Density/km²
# 0          412
# 1          231
# 2          258
# 3          278
# 4          552

# %%
df_ht.dtypes
# Out:
# Département              object
# Chef-Lieu ou Capitale    object
# Superficie (km²)          int64
# adm0code                 object
# Population                int64
# Density/km²               int64
# dtype: object

# %%
# Using the instance of Geopy to retrieve geographical coordinates for each Department
start = time.time()

df_ht['address'] = df_ht['Chef-Lieu ou Capitale'] +', '+ df_ht['adm0code']
df_ht['lat'] = df_ht['address'].apply(lambda x: geolocator.geocode(x).latitude )
df_ht['lon'] = df_ht['address'].apply(lambda x: geolocator.geocode(x).longitude )
df_ht['address'] = df_ht['address'].apply(lambda x: geolocator.geocode(x).address )

end = time.time()
print(f'This cell took exactly {end-start} secondes to execute')

display(df_ht.head())
# Out:
# This cell took exactly 19.913043975830078 secondes to execute
#    Département Chef-Lieu ou Capitale  Superficie (km²) adm0code  Population  \
# 0   Artibonite          Les Gonaïves              4984       HT     2047152
# 1       Centre                Hinche              3675       HT      845594
# 2  Grande'Anse               Jérémie              1871       HT      481065
# 3       Nippes             Miragoâne              1268       HT      351593
# 4         Nord           Cap-Haïtien              2106       HT     1159761
#
#    Density/km²                                            address        lat  \
# 0          412  Les Gonaïves, Arrondissement des Gonaïves, Dép...  19.446060
# 1          231  Hinche, Arrondissement de Hinche, Département ...  19.144554
# 2          258  Jérémie, Arrondissement de Jérémie, Départemen...  18.644583
# 3          278  Miragoâne, Arrondissement de Miragoâne, Départ...  18.444843
# 4          552  Cap-Haïtien, Arrondissement de Cap-Haïtien, Dé...  19.759524
#
#          lon
# 0 -72.688434
# 1 -72.008753
# 2 -74.113918
# 3 -73.088639
# 4 -72.200807

# %%
df_ht_healthsites = pd.read_csv(r'../input/haiti-healthsites.csv')
df_ht_healthsites.head()
# Out:
#   Adm1code        adm1_fr         adm1_ht    adm2code         adm2_en  \
# 0      NaN  #adm1+name+fr  #adm1+tname+ht  #adm2+code   #adm2+name+en
# 1     HT01          Ouest            Lwès      HT0111  Port-au-Prince
# 2     HT01          Ouest            Lwès      HT0111  Port-au-Prince
# 3     HT01          Ouest            Lwès      HT0111  Port-au-Prince
# 4     HT01          Ouest            Lwès      HT0111  Port-au-Prince
#
#           adm2_fr    adm3code              adm3_en              adm3_fr  \
# 0   #adm2+name+fr  #adm3+code        #adm3+name+en        #adm3+name+fr
# 1  Port-au-Prince   HT0111-01  1re Section Turgeau  1re Section Turgeau
# 2  Port-au-Prince   HT0111-01  1re Section Turgeau  1re Section Turgeau
# 3  Port-au-Prince   HT0111-01  1re Section Turgeau  1re Section Turgeau
# 4  Port-au-Prince   HT0111-01  1re Section Turgeau  1re Section Turgeau
#
#                      Institution name    Catégorie      Institution_Type  \
# 0                           #loc+name      #loc+id             #loc+type
# 1              Centre de Santé Snelak  Dispensaire  Privé à but lucratif
# 2  Centre de psychiatrie Mars & Kline          HCR                Public
# 3       Hôpital St. François de Salle          CSL  Privé à but lucratif
# 4                           CSL SODEC          CAL  Privé à but lucratif
#
#   Institution_Code      LatDD      LongDD
# 0        #loc+code       #lat       #long
# 1           111607  18,525922  -72,335068
# 2           111616  18,525922  -72,335068
# 3           111618  18,537777  -72,344001
# 4           111619  18,525922  -72,335068

# %%
df_ht_healthsites.drop(0, axis=0, inplace=True)
df_ht_healthsites.reset_index(drop=True, inplace = True)
df_ht_healthsites.head()
# Out:
#   Adm1code adm1_fr adm1_ht adm2code         adm2_en         adm2_fr  \
# 0     HT01   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 1     HT01   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 2     HT01   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 3     HT01   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
# 4     HT01   Ouest    Lwès   HT0111  Port-au-Prince  Port-au-Prince
#
#     adm3code              adm3_en              adm3_fr  \
# 0  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 1  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 2  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 3  HT0111-01  1re Section Turgeau  1re Section Turgeau
# 4  HT0111-01  1re Section Turgeau  1re Section Turgeau
#
#                      Institution name    Catégorie          Institution_Type  \
# 0              Centre de Santé Snelak  Dispensaire      Privé à but lucratif
# 1  Centre de psychiatrie Mars & Kline          HCR                    Public
# 2       Hôpital St. François de Salle          CSL      Privé à but lucratif
# 3                           CSL SODEC          CAL      Privé à but lucratif
# 4                          PROFAMIL 2          CSL  Privé à but non lucratif
#
#   Institution_Code      LatDD      LongDD
# 0           111607  18,525922  -72,335068
# 1           111616  18,525922  -72,335068
# 2           111618  18,537777  -72,344001
# 3           111619  18,525922  -72,335068
# 4           111620  18,525922  -72,335068

# %%
df_ht_healthsites['Catégorie'].unique()
# Out:
# array(['Dispensaire', 'HCR', 'CSL', 'CAL', 'Hôpital', 'HU', 'HD',
#        'Hôpital spécial.', 'Point Fixe', nan], dtype=object)

# %%
df_ht_healthsites_count = df_ht_healthsites.groupby('adm1_fr').count().reset_index()[['adm1_fr','Institution name']]
df_ht_healthsites_count
# Out:
#        adm1_fr  Institution name
# 0   Artibonite               436
# 1       Centre               100
# 2  Grande'Anse                 0
# 3       Nippes                 0
# 4         Nord                68
# 5     Nord-Est                 0
# 6   Nord-Ouest                 0
# 7        Ouest               126
# 8          Sud                 0
# 9      Sud-Est                 0

# %% [markdown]
# ## I'm not happy with this dataset because of too many zeros
# ### Let's retrieve a new one from the OpenStreetMap API

# %%
amenity_list = ['hospital', 'clinic', 'doctors', 'pharmacy']
country_ht, type_ht, lat_ht, lon_ht, categ_ht, name_ht = [], [], [], [], [], []

for amen in amenity_list[:2]:    
    overpass_url = "http://overpass-api.de/api/interpreter"
    overpass_query = f'[out:json][timeout:25];area["ISO3166-1"="HT"][admin_level=2];(node["amenity"={amen}](area);way["amenity"={amen}](area);rel["amenity"={amen}](area););out center;'
    
    response_ht = requests.get(overpass_url, 
                            params={'data': overpass_query},timeout=10)
    data_ht = response_ht.json()
    
    print('------------------------------------'+amen)
    
    for element in data_ht['elements']:
        country_ht.append('HT')
        type_ht.append(element['type'])
        lat_ht.append(element['lat'])
        lon_ht.append(element['lon'])
        categ_ht.append(element['tags']['amenity'])
        if 'name' in element['tags'].keys():
            name_ht.append(element['tags']['name'])
            print(element['tags']['name'])
        else:
            name_ht.append('unknown name')
            print('Unknown')
    time.sleep(2)
# Out:
# ------------------------------------hospital
# HOPITAL LA PROVIDENCE
# Le Sourire
# Dispensaire "N.D. des Malades"
# French Hospital
# Help Hospital
# Croix-Rouge
# Orthopedic clinic
# Universal Medical Centre
# Hôpital de l'Ofatma (Cité Militaire)
# Clinique de la Sante
# Citymed Petion-Ville
# Maternité de Christ Roi
# Centre Materno-Chirurgical
# Clinic de Reference
# Complexe Materno-Medico
# Sante Pep La
# PIGNON HOSPITAL LA JEUNE
# Rehabilitation de l'Hopital
# Hospital Grande Rivière du Nord
# Hôpital Raboteau
# Hôpital-Maternité Sapiens
# MSF Orthopedic Hospital Carrefour
# St. Vincent
# Hospital Raboteau
# Hospital Eglise Wesleyan Fauché
# Hospital La Saline (Pediatrie Sociale)
# Hôpital Saint Ésprit
# Hospital Bonneau St. Joseph
# Hospital Bonne Fin
# Hospital Bethel Fonds-des-Nègres / Armée du Salut
# Centre de Santé la Visitation Petite Rivière de Nippes
# Hospital La Sainte Famille
# Hopital Maternite Mathieu
# College Excelsior
# Hospital De La Communauté
# Centre Médico-Social Populorum Progressio
# Hospital Bon Berger
# Centre De Psychiatrie Et De Neurologie Mars
# Hospital Bombardopolis
# Hospital Docteur Baudin
# Hospital Beraca La Pointe
# Citymed
# Unknown
# field clinic
# King's Hospital
# ISRAELI FIELD HOSPITAL
# CENTRE DE SANTE DE BAINET
# Maternité des Abricots
# DISPENSAIRE ROY - SEC
# DP DE BOSSOU
# DP DE CHRISTANT (SOE)
# DP DE DESCHAPELLES
# DP DE DESARMES (SOE)
# DP COMMUNAUTAIRE DE MARIN
# Dispensaire de Mont-Rouis
# DP DE GRESSOT
# DP MAX FERDINAND
# DP DE CHARETTE
# DISPENSAIRE SAINT LOUIS
# DP DE SEGUR
# DP CLEMENTINE ET LORISMENE
# CENTRE MEDICAL DE LA RHEMA
# DP PA NOU AN
# DP BEREE DE DROUIN
# Unknown
# Snerrose Polyclinique
# Clinique de Dieu le tout Puissant
# Clinique Communautaire Jésus est Le Vrai Chemin
# Plyclinique Evangélique Bethesda
# Organisation Sociale de Santé et Pour le Developpemant D'onaville
# Clinico JeJica ,Medicale Communautaire Jehovah Jiré de canaan
# Ramantial Aguavivo
# Unknown
# Unknown
# Unknown
# La Renaissance de Jerusalem
# Clinique medicale Bethel
# Centre de santé Saint Jude
# Clinique des Cèdres
# Siloe Medical Center
# Centre de Santé de St Christophe
# Zanmi Lasanté
# Clinique Evangelique De La Grace
# Mitho Centre De Santé
# Succès Centre De Santé
# Unknown
# Centre Médico-Pharma De Sainte Anne
# Unknown
# Service de 1er Soin
# Clinique Dentaire
# Eben Ezer
# Unknown
# Clinique Dentaire
# Clinique Emmanuel
# Centre Anti-Tuberculose Abricots
# Centre Anti-Tuberculose (Mission Mennonite en Haiti)
# Sant Sante (Mission Mennonite en Haiti)
# Poste de Santé Gaspard Camara
# La Référence
# HHF_Clinique
# Clinique Le Samaritain
# Clinique Medicale
# Docteur Pierre Louis
# Clinique Docteur Adelin Pierre
# Clinique ophtalmologiste
# Clinique medicale de duvivier
# Docteur Benjamain
# Unknown
# Polyclinique de Meyotte
# CEDREMI
# Clinic du Lycee Jean-Baptiste Point du Sable
# Clinique du Sacre-Coeur Pediatre
# Dispensaire CCS de Pont Sonde
# Centre Obstétrique Holy
# Met Lab
# Polyclinique Saint Esprit
# Unknown
# Unknown
# Clinique d’Urgences Médicales
# Unknown
# Centre de santé sexuelle pour adolescents
# Clinique Médico Chirurgicale Digue
# Unknown
# Clinique Médicale des Yeux
# Karen Polyclinique
# Sant Medikal Besdon
# Geb Clinique

# %%
for amen in amenity_list[2:]:    
    overpass_url = "http://overpass-api.de/api/interpreter"
    overpass_query = f'[out:json][timeout:25];area["ISO3166-1"="HT"][admin_level=2];(node["amenity"={amen}](area);way["amenity"={amen}](area);rel["amenity"={amen}](area););out center;'
    
    response_ht = requests.get(overpass_url, 
                            params={'data': overpass_query},timeout=10)
    data_ht = response_ht.json()
    
    print('------------------------------------'+amen)
    
    for element in data_ht['elements']:
        country_ht.append('HT')
        type_ht.append(element['type'])
        lat_ht.append(element['lat'])
        lon_ht.append(element['lon'])
        categ_ht.append(element['tags']['amenity'])
        if 'name' in element['tags'].keys():
            name_ht.append(element['tags']['name'])
            print(element['tags']['name'])
        else:
            name_ht.append('unknown name')
            print('Unknown')
    time.sleep(2)
# Out:
# ------------------------------------doctors
# Clinic
# Clinic Roger Emmanuel
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# Unknown
# l'Arche des Enfants
# mayte
# Unknown
# Clinique Saint Soleil
# Centre de Santé Familiale
# complexe medico-chirurgical,bon samaritain
# clinique medical
# Sant medical Santo 20
# Obstetrique-Gynecologue
# Clinique Medico Docteur Claupha
# Centre Medical Joseph Edmond et Pharmacie
# Clinipharma Ma sante
# Clinique Beaulieu
# Clinique medicale Chirurgicale et Steri Lab Laboratoire medical
# Dental office Radiographie
# MEDITEL SA
# Unknown
# Alpha Medical Supplies
# Prophalab
# Caribbean Canadian Chemical Company (4C)
# Makensky Medical Supplies
# IMEDIS Medical Supplies
# Pharmacie
# Mendeleïev
# Pharmacie
# Judith Pharma
# Pharmacie de l’Espoir
# Saba Pharma
# Pharmacie de l'Espoir
# Unknown
# Pharmacie Saint Géraud
# Chi-Pharma
# Unknown
# Pharmacie de Bois Verna
# Pharmacie Saint Charbel
# Manou pharma
# Pharmacie de Gressier
# Lorency's Pharma
# Pharmacie Jésus Miséricorde
# Unknown
# Pharmacie Lavoisier
# Pharmacie du Bon Berger
# Vittamet
# Unknown
# Unknown
# Unknown
# Pharmacie de Canaan
# Pharmacie Pauline Leclerc
# Pharmacie Lakay
# Pharmacie Guérison Plus
# Pharmacie Propharmax
# Vision Pharma
# Unknown
# Pharma Eagle
# Pharmacie Sundi
# Omega Pharma
# Pharmep
# Pharmacie Don de Dieu
# Unknown
# Jude Pharma
# Pharmacie Solitude
# Pharmacie Francilia
# Pharmacie Andréa
# Drug Store Pharma
# Pharmacie Gracieuse
# Unknown
# Unknown
# Unknown
# Joseph Pharmacie
# Chi Pharma 2
# Joa Pharma
# Unknown
# Christ Pharma
# Mteg Pharma
# Pharmacie Coseco
# Pharma Dens
# Unipharma Plus
# Victor Pharma
# Alie Pharma
# Unknown
# Unknown
# Unknown
# Pharmacie Carouss
# Pharmacie Oasis Pharma

# %%
df_health = pd.DataFrame({'Name':name_ht, 'Type':type_ht, 'Category':categ_ht, 'Country':country_ht, 'lat':lat_ht, 'lon':lon_ht})

# %%
df_health.head()
# Out:
#                              Name  Type  Category Country        lat  \
# 0           HOPITAL LA PROVIDENCE  node  hospital      HT  19.450206
# 1                      Le Sourire  node  hospital      HT  18.508700
# 2  Dispensaire "N.D. des Malades"  node  hospital      HT  18.191978
# 3                 French Hospital  node  hospital      HT  18.540614
# 4                   Help Hospital  node  hospital      HT  18.505910
#
#          lon
# 0 -72.685424
# 1 -72.630274
# 2 -73.744801
# 3 -72.316322
# 4 -72.625009

# %%
df_health['geocode'] = df_health.lat.astype('str') + ' , ' + df_health.lon.astype('str')
df_health.head()
# Out:
#                              Name  Type  Category Country        lat  \
# 0           HOPITAL LA PROVIDENCE  node  hospital      HT  19.450206
# 1                      Le Sourire  node  hospital      HT  18.508700
# 2  Dispensaire "N.D. des Malades"  node  hospital      HT  18.191978
# 3                 French Hospital  node  hospital      HT  18.540614
# 4                   Help Hospital  node  hospital      HT  18.505910
#
#          lon                   geocode
# 0 -72.685424    19.450206 , -72.685424
# 1 -72.630274  18.5087003 , -72.6302745
# 2 -73.744801  18.1919778 , -73.7448006
# 3 -72.316322  18.5406142 , -72.3163221
# 4 -72.625009  18.5059105 , -72.6250088

# %%
a = time.time()

df_health['Département'] = df_health.geocode.apply(lambda x: geolocator.reverse(x).raw['address']['state'])
df_health.head()

b = time.time()

print(f'This code took exactly {b-a} secondes to exectute')
# Out:
# This code took exactly 1016.1661229133606 to exectute

# %%
# Backup this dataframe as it takes too long to get
df_health_copy = df_health.copy()

# %%
# Create a list of prefix to rename every single element in the 'Département' column
list__ = ["Département de l'", 'Département du ', 'Département des ', 'Département de la ']

for replacer in list__:
    df_health['Département'] = df_health['Département'].str.replace(replacer, '')
    
df_health.head()
# Out:
#                              Name  Type  Category Country        lat  \
# 0           HOPITAL LA PROVIDENCE  node  hospital      HT  19.450206
# 1                      Le Sourire  node  hospital      HT  18.508700
# 2  Dispensaire "N.D. des Malades"  node  hospital      HT  18.191978
# 3                 French Hospital  node  hospital      HT  18.540614
# 4                   Help Hospital  node  hospital      HT  18.505910
#
#          lon                   geocode Département
# 0 -72.685424    19.450206 , -72.685424  Artibonite
# 1 -72.630274  18.5087003 , -72.6302745       Ouest
# 2 -73.744801  18.1919778 , -73.7448006         Sud
# 3 -72.316322  18.5406142 , -72.3163221       Ouest
# 4 -72.625009  18.5059105 , -72.6250088       Ouest

# %%
# Display the unique elements of the 'Département' column
df_health['Département'].unique()
# Out:
# array(['Artibonite', 'Ouest', 'Sud', 'Nord-Est', 'Nord-Ouest', 'Nord',
#        'Nippes', 'Sud-Est', 'Grande-Anse', 'Centre'], dtype=object)

# %%
# Replace value to reach our naming convention for departments
df_health['Département'] = df_health['Département'].replace('Grande-Anse',"Grande'Anse")

# %%
df_health.shape
# Out:
# (2002, 8)

# %%
df_health[df_health.Category == 'hospital'].groupby('Département').count()
# Out:
#              Name  Type  Category  Country  lat  lon  geocode
# Département
# Artibonite    184   184       184      184  184  184      184
# Centre         73    73        73       73   73   73       73
# Grande'Anse    64    64        64       64   64   64       64
# Nippes         38    38        38       38   38   38       38
# Nord          107   107       107      107  107  107      107
# Nord-Est       55    55        55       55   55   55       55
# Nord-Ouest     89    89        89       89   89   89       89
# Ouest         415   415       415      415  415  415      415
# Sud           111   111       111      111  111  111      111
# Sud-Est        78    78        78       78   78   78       78

# %%
df_health[df_health.Category == 'doctors'].groupby('Département').count()
# Out:
#              Name  Type  Category  Country  lat  lon  geocode
# Département
# Artibonite     17    17        17       17   17   17       17
# Nord            7     7         7        7    7    7        7
# Ouest          32    32        32       32   32   32       32
# Sud             9     9         9        9    9    9        9
# Sud-Est         1     1         1        1    1    1        1

# %%
df_health[df_health.Category == 'clinic'].groupby('Département').count()
# Out:
#              Name  Type  Category  Country  lat  lon  geocode
# Département
# Artibonite     10    10        10       10   10   10       10
# Grande'Anse     4     4         4        4    4    4        4
# Nippes          1     1         1        1    1    1        1
# Nord           30    30        30       30   30   30       30
# Nord-Est       23    23        23       23   23   23       23
# Nord-Ouest      2     2         2        2    2    2        2
# Ouest          74    74        74       74   74   74       74
# Sud             3     3         3        3    3    3        3
# Sud-Est         1     1         1        1    1    1        1

# %%
df_health[df_health.Category == 'pharmacy'].groupby(['Département', 'Category']).count()
# Out:
#                       Name  Type  Country  lat  lon  geocode
# Département Category
# Artibonite  pharmacy    81    81       81   81   81       81
# Centre      pharmacy    21    21       21   21   21       21
# Grande'Anse pharmacy     7     7        7    7    7        7
# Nord        pharmacy    45    45       45   45   45       45
# Nord-Est    pharmacy    56    56       56   56   56       56
# Nord-Ouest  pharmacy     5     5        5    5    5        5
# Ouest       pharmacy   273   273      273  273  273      273
# Sud         pharmacy    62    62       62   62   62       62
# Sud-Est     pharmacy    24    24       24   24   24       24

# %%
# Exporting the dataframe to a csv dataset
df_health.to_csv(r'../output/Notebook 1/haiti-healthsites-by-department.csv', index = False)

# %%
# Create new dataframe to display number of health facilities by department and by category
distribution_by_dept = df_health.groupby(['Département', 'Category']).count().reset_index().rename(columns={'Name':'count'})[['Département','Category','count']]
display(distribution_by_dept.head())

# Displaying the dataframe of Haiti departments so we can figure out what to fix for a better merging
display(df_ht.head())
# Out:
#   Département  Category  count
# 0  Artibonite    clinic     10
# 1  Artibonite   doctors     17
# 2  Artibonite  hospital    184
# 3  Artibonite  pharmacy     81
# 4      Centre  hospital     73
#    Département Chef-Lieu ou Capitale  Superficie (km²) adm0code  Population  \
# 0   Artibonite          Les Gonaïves              4984       HT     2047152
# 1       Centre                Hinche              3675       HT      845594
# 2  Grande'Anse               Jérémie              1871       HT      481065
# 3       Nippes             Miragoâne              1268       HT      351593
# 4         Nord           Cap-Haïtien              2106       HT     1159761
#
#    Density/km²                                            address        lat  \
# 0          412  Les Gonaïves, Arrondissement des Gonaïves, Dép...  19.446060
# 1          231  Hinche, Arrondissement de Hinche, Département ...  19.144554
# 2          258  Jérémie, Arrondissement de Jérémie, Départemen...  18.644583
# 3          278  Miragoâne, Arrondissement de Miragoâne, Départ...  18.444843
# 4          552  Cap-Haïtien, Arrondissement de Cap-Haïtien, Dé...  19.759524
#
#          lon
# 0 -72.688434
# 1 -72.008753
# 2 -74.113918
# 3 -73.088639
# 4 -72.200807

# %%
# Check whether the 'Département' column of both of the dataframes are identicals
is_diff(distribution_by_dept['Département'], df_ht['Département'])
# Out:
# {'Grande-Anse'}

# %%
# Replace value to reach our naming convention for departments
distribution_by_dept['Département'] = distribution_by_dept['Département'].replace('Grande-Anse',"Grande'Anse")
distribution_by_dept['Département'].unique()
# Out:
# array(['Artibonite', 'Centre', "Grande'Anse", 'Nippes', 'Nord',
#        'Nord-Est', 'Nord-Ouest', 'Ouest', 'Sud', 'Sud-Est'], dtype=object)

# %%
# Check whether the 'Département' column of both of the dataframes are identical
is_diff(distribution_by_dept['Département'], df_ht['Département'])
# Out:
# Absolutely no difference

# %%
distribution_by_dept.head()
# Out:
#   Département  Category  count
# 0  Artibonite    clinic     10
# 1  Artibonite   doctors     17
# 2  Artibonite  hospital    184
# 3  Artibonite  pharmacy     81
# 4      Centre  hospital     73

# %%
# Backup dataframe
df_ht_copy = df_ht.copy()

# %%
# Loop through departments to retrieve number of facilities by category

for dept in distribution_by_dept['Département'].unique().tolist():
    # List of category available by department
    categ = distribution_by_dept[distribution_by_dept['Département'] == dept]['Category'].unique().tolist()
    for cat in categ:
        df_ht.loc[df_ht['Département'] == dept, cat] = df_health.groupby(['Département', 'Category']).count().T.reset_index()[dept][cat][0]

df_ht.fillna(0, inplace = True)

if df_ht.shape[0] == 11:
    df_ht.drop(df_ht.index[-1], axis=0, inplace = True)
        
df_ht
# Out:
#    Département Chef-Lieu ou Capitale  Superficie (km²) adm0code  Population  \
# 0   Artibonite          Les Gonaïves              4984       HT     2047152
# 1       Centre                Hinche              3675       HT      845594
# 2  Grande'Anse               Jérémie              1871       HT      481065
# 3       Nippes             Miragoâne              1268       HT      351593
# 4         Nord           Cap-Haïtien              2106       HT     1159761
# 5     Nord-Est          Fort-Liberté              1805       HT      444463
# 6   Nord-Ouest          Port-de-Paix              2176       HT      868580
# 7        Ouest        Port-au-Prince              4827       HT     5010205
# 8          Sud             Les Cayes              2794       HT      791084
# 9      Sud-Est                Jacmel              2023       HT      893900
#
#    Density/km²                                            address        lat  \
# 0          412  Les Gonaïves, Arrondissement des Gonaïves, Dép...  19.446060
# 1          231  Hinche, Arrondissement de Hinche, Département ...  19.144554
# 2          258  Jérémie, Arrondissement de Jérémie, Départemen...  18.644583
# 3          278  Miragoâne, Arrondissement de Miragoâne, Départ...  18.444843
# 4          552  Cap-Haïtien, Arrondissement de Cap-Haïtien, Dé...  19.759524
# 5          247  Fort-Liberté, Arrondissement de Fort-Liberté, ...  19.663561
# 6          400  Port-de-Paix, Arrondissement Port-de-Paix, Dép...  19.938986
# 7         1039  Port-au-Prince, Arrondissement de Port-au-Prin...  18.547327
# 8          284  Commune Les Cayes, Arrondissement des Cayes, D...  18.194443
# 9          443  Jacmel, Arrondissement de Jacmel, Département ...  18.235259
#
#          lon  clinic  doctors  hospital  pharmacy
# 0 -72.688434    10.0     17.0     184.0      81.0
# 1 -72.008753     0.0      0.0      73.0      21.0
# 2 -74.113918     4.0      0.0      64.0       7.0
# 3 -73.088639     1.0      0.0      38.0       0.0
# 4 -72.200807    30.0      7.0     107.0      45.0
# 5 -71.836705    23.0      0.0      55.0      56.0
# 6 -72.830813     2.0      0.0      89.0       5.0
# 7 -72.339593    74.0     32.0     415.0     273.0
# 8 -73.751160     3.0      9.0     111.0      62.0
# 9 -72.537513     1.0      1.0      78.0      24.0

# %%
df_ht.to_csv(r'../output/Notebook 1/number-of-facilities-by-department_ht.csv', index = False)

# %% [markdown]
# ## Now let's retrieve data from the COVID-19 by department from a legal document

# %%
sitrep = pd.read_excel(r'../input/sitrep_covid.xlsx', sheet_name = None)

# %%
sitrep.keys()
# Out:
# dict_keys(['Table 1', 'Table 2', 'Table 3', 'Table 4', 'Table 5', 'Table 6', 'Table 7', 'Table 8', 'Table 9', 'Table 10', 'Table 11', 'Table 12', 'Table 13', 'Table 14', 'Table 15', 'Table 16', 'Table 17', 'Table 18', 'Table 19', 'Table 20', 'Table 21', 'Table 22', 'Table 23', 'Table 24', 'Table 25', 'Table 26', 'Table 27', 'Table 28', 'Table 29', 'Table 30', 'Table 31', 'Table 32', 'Table 33', 'Table 34', 'Table 35'])

# %%
covid_haiti = sitrep['Table 4']
covid_haiti.rename(columns={'Unnamed: 6': 'létalité','Unnamed: 0': 'Département', 'Unnamed: 1': 'Cas cumulés', '(24h)':'Nouveau cas', 'Unnamed: 3':'Décès cumulés', 'décès (24h)': 'Nouveaux décès'}, inplace = True)
covid_haiti.drop(10, axis=0, inplace = True)
covid_haiti['Département'] = covid_haiti['Département'].replace('Grand Anse', "Grande'Anse")
covid_haiti
# Out:
#    Département  Cas cumulés  Nouveau cas  Décès cumulés  Nouveaux décès  \
# 0        Ouest         5377            9             73               3
# 1   Artibonite          443            0             34               1
# 2       Centre          378            0              5               1
# 3         Nord          360            3             25               0
# 4      Sud-Est          215            0              8               0
# 5          Sud          210            0              6               0
# 6     Nord-Est          180            0              5               0
# 7   Nord-Ouest          170            0             10               0
# 8  Grande'Anse          154            0             12               0
# 9       Nippes          124            0              4               0
#
#    positivité  létalité
# 0       0.396     0.014
# 1       0.395     0.077
# 2       0.447     0.013
# 3       0.471     0.069
# 4       0.483     0.037
# 5       0.544     0.029
# 6       0.235     0.028
# 7       0.424     0.059
# 8       0.470     0.078
# 9       0.399     0.032

# %%
covid_haiti.to_csv(r'../output/Notebook 1/covid_haiti.csv', index = False)

# %% [markdown]
# ---

# %% [markdown]
# ### Put this error on purpose to prevent the notebook from running the cells below

# %%
error_on_purpose =

# %% [markdown]
# world = pd.read_csv(r'../input/worldcities.csv')
# world.head()

# %% [markdown]
# dom = world[world['iso2'] == 'DO']
# dom.head()

# %% [markdown]
# dom.shape

# %% [markdown]
# dom.groupby(['city', 'admin_name']).count().shape

# %% [markdown]
# ---

# %%
# Use the wikipedia module to retrieve data for Dominican Republic
wp.set_lang('en')
html1 = wp.page(r"Provinces_of_the_Dominican_Republic").html()
dom1 = pd.read_html(html1, header = 0)[1]
dom1.head()
# Out:
#             Province        Capital  Area (km²)[5]  Population[4]  Density[5]
# 0               Azua           Azua        2531.77         298246         118
# 1            Baoruco          Neiba        1282.23         111269          87
# 2           Barahona       Barahona        1739.38         232818         134
# 3            Dajabón        Dajabón        1020.73          87274          86
# 4  Distrito Nacional  Santo Domingo         104.44        1402749       13431

# %% [markdown]
# display(dom.head())

# %%
display(dom1.head())
# Out:
#             Province        Capital  Area (km²)[5]  Population[4]  Density[5]
# 0               Azua           Azua        2531.77         298246         118
# 1            Baoruco          Neiba        1282.23         111269          87
# 2           Barahona       Barahona        1739.38         232818         134
# 3            Dajabón        Dajabón        1020.73          87274          86
# 4  Distrito Nacional  Santo Domingo         104.44        1402749       13431

# %%
dom2 = pd.read_excel(r"C:\Users\dadyf\Downloads\dom_admgz_2020.xlsx", sheet_name = None)
dom2.keys()
# Out:
# dict_keys(['dom_gz_adm0', 'dom_gz_adm1', 'dom_gz_adm2', 'dom_gz_adm3', 'dom_gz_adm4'])

# %%
display(dom2['dom_gz_adm2'].head())
print(dom2['dom_gz_adm2'].shape)
# Out:
#               ADM0_EN               ADM0_ES ADM0_PCODE                ADM1_ES  \
# 0  Dominican Republic  República Dominicana         DO  Región Cibao Nordeste
# 1  Dominican Republic  República Dominicana         DO  Región Cibao Nordeste
# 2  Dominican Republic  República Dominicana         DO  Región Cibao Nordeste
# 3  Dominican Republic  República Dominicana         DO  Región Cibao Nordeste
# 4  Dominican Republic  República Dominicana         DO  Región Cibao Noroeste
#
#                 ADM2_REF ADM1_PCODE                           ADM2_ES  \
# 0  Region Cibao Nordeste       DO01                  Provincia Duarte
# 1  Region Cibao Nordeste       DO01        Provincia Hermanas Mirabal
# 2  Region Cibao Nordeste       DO01  Provincia María Trinidad Sánchez
# 3  Region Cibao Nordeste       DO01                  Provincia Samaná
# 4  Region Cibao Noroeste       DO02                 Provincia Dajabón
#
#                          ADM2_REF.1 ADM2_PCODE
# 0                  Provincia Duarte     DO0101
# 1        Provincia Hermanas Mirabal     DO0102
# 2  Provincia Maria Trinidad Sanchez     DO0103
# 3                  Provincia Samana     DO0104
# 4                 Provincia Dajabon     DO0201
# (32, 9)

# %%
dom2['dom_gz_adm2']['ADM2_ES'].unique()
# Out:
# array(['Provincia Duarte', 'Provincia Hermanas Mirabal',
#        'Provincia María Trinidad Sánchez', 'Provincia Samaná',
#        'Provincia Dajabón', 'Provincia Monte Cristi',
#        'Provincia Santiago Rodríguez', 'Provincia Valverde',
#        'Provincia Espaillat', 'Provincia Puerto Plata',
#        'Provincia Santiago', 'Provincia La Vega',
#        'Provincia Monseñor Nouel', 'Provincia Sánchez Ramírez',
#        'Provincia Elías Piña', 'Provincia San Juan', 'Provincia Baoruco',
#        'Provincia Barahona', 'Provincia Independencia',
#        'Provincia Pedernales', 'Provincia Hato Mayor',
#        'Provincia Monte Plata', 'Provincia San Pedro de Macorís',
#        'Distrito Nacional', 'Provincia Santo Domingo', 'Provincia Azua',
#        'Provincia Peravia', 'Provincia San Cristóbal',
#        'Provincia San José de Ocoa', 'Provincia El Seibo',
#        'Provincia La Altagracia', 'Provincia La Romana'], dtype=object)

# %%
df_4 = dom2['dom_gz_adm2'][['ADM0_PCODE','ADM2_ES', 'ADM2_REF.1']]
df_4.head()
# Out:
#   ADM0_PCODE                           ADM2_ES  \
# 0         DO                  Provincia Duarte
# 1         DO        Provincia Hermanas Mirabal
# 2         DO  Provincia María Trinidad Sánchez
# 3         DO                  Provincia Samaná
# 4         DO                 Provincia Dajabón
#
#                          ADM2_REF.1
# 0                  Provincia Duarte
# 1        Provincia Hermanas Mirabal
# 2  Provincia Maria Trinidad Sanchez
# 3                  Provincia Samana
# 4                 Provincia Dajabon

# %%
df_4['ADM2_ES'] = df_4['ADM2_ES'].str.replace('Provincia ','')
# Out:
# C:\Users\dadyf\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_4.head()
# Out:
#   ADM0_PCODE                 ADM2_ES                        ADM2_REF.1
# 0         DO                  Duarte                  Provincia Duarte
# 1         DO        Hermanas Mirabal        Provincia Hermanas Mirabal
# 2         DO  María Trinidad Sánchez  Provincia Maria Trinidad Sanchez
# 3         DO                  Samaná                  Provincia Samana
# 4         DO                 Dajabón                 Provincia Dajabon

# %%
df_4['ADM2_ES']
# Out:
# 0                     Duarte
# 1           Hermanas Mirabal
# 2     María Trinidad Sánchez
# 3                     Samaná
# 4                    Dajabón
# 5               Monte Cristi
# 6         Santiago Rodríguez
# 7                   Valverde
# 8                  Espaillat
# 9               Puerto Plata
# 10                  Santiago
# 11                   La Vega
# 12            Monseñor Nouel
# 13           Sánchez Ramírez
# 14                Elías Piña
# 15                  San Juan
# 16                   Baoruco
# 17                  Barahona
# 18             Independencia
# 19                Pedernales
# 20                Hato Mayor
# 21               Monte Plata
# 22      San Pedro de Macorís
# 23         Distrito Nacional
# 24             Santo Domingo
# 25                      Azua
# 26                   Peravia
# 27             San Cristóbal
# 28          San José de Ocoa
# 29                  El Seibo
# 30             La Altagracia
# 31                 La Romana
# Name: ADM2_ES, dtype: object

# %%
df_4['address'] = df_4['ADM2_ES'] +', '+ df_4['ADM0_PCODE']
# Out:
# C:\Users\dadyf\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_4.head()
# Out:
#   ADM0_PCODE                 ADM2_ES                        ADM2_REF.1  \
# 0         DO                  Duarte                  Provincia Duarte
# 1         DO        Hermanas Mirabal        Provincia Hermanas Mirabal
# 2         DO  María Trinidad Sánchez  Provincia Maria Trinidad Sanchez
# 3         DO                  Samaná                  Provincia Samana
# 4         DO                 Dajabón                 Provincia Dajabon
#
#                       address
# 0                  Duarte, DO
# 1        Hermanas Mirabal, DO
# 2  María Trinidad Sánchez, DO
# 3                  Samaná, DO
# 4                 Dajabón, DO

# %%
df_4['lat'] = df_4['address'].apply(lambda x: geolocator.geocode(x).latitude )
df_4['lon'] = df_4['address'].apply(lambda x: geolocator.geocode(x).longitude )
df_4['address'] = df_4['address'].apply(lambda x: geolocator.geocode(x).address )
# Out:
# C:\Users\dadyf\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\dadyf\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\dadyf\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_4.head()
# Out:
#   ADM0_PCODE                 ADM2_ES                        ADM2_REF.1  \
# 0         DO                  Duarte                  Provincia Duarte
# 1         DO        Hermanas Mirabal        Provincia Hermanas Mirabal
# 2         DO  María Trinidad Sánchez  Provincia Maria Trinidad Sanchez
# 3         DO                  Samaná                  Provincia Samana
# 4         DO                 Dajabón                 Provincia Dajabon
#
#                                         address        lat        lon
# 0                  Duarte, República Dominicana  19.243456 -70.087743
# 1        Hermanas Mirabal, República Dominicana  19.408967 -70.392841
# 2  María Trinidad Sánchez, República Dominicana  19.444598 -69.984468
# 3                  Samaná, República Dominicana  19.264811 -69.493002
# 4                 Dajabón, República Dominicana  19.458693 -71.602296

# %%
display(df_ht.head())
display(dom1.head())
display(df_4.head())
# Out:
#    Département Chef-Lieu ou Capitale  Superficie (km²) adm0code  Population  \
# 0   Artibonite          Les Gonaïves              4984       HT     2047152
# 1       Centre                Hinche              3675       HT      845594
# 2  Grande'Anse               Jérémie              1871       HT      481065
# 3       Nippes             Miragoâne              1268       HT      351593
# 4         Nord           Cap-Haïtien              2106       HT     1159761
#
#    Density/km²                                            address        lat  \
# 0          412  Les Gonaïves, Arrondissement des Gonaïves, Dép...  19.446060
# 1          231  Hinche, Arrondissement de Hinche, Département ...  19.144554
# 2          258  Jérémie, Arrondissement de Jérémie, Départemen...  18.644583
# 3          278  Miragoâne, Arrondissement de Miragoâne, Départ...  18.444843
# 4          552  Cap-Haïtien, Arrondissement de Cap-Haïtien, Dé...  19.759524
#
#          lon
# 0 -72.688434
# 1 -72.008753
# 2 -74.113918
# 3 -73.088639
# 4 -72.200807
#             Province        Capital  Area (km²)[5]  Population[4]  Density[5]
# 0               Azua           Azua        2531.77         298246         118
# 1            Baoruco          Neiba        1282.23         111269          87
# 2           Barahona       Barahona        1739.38         232818         134
# 3            Dajabón        Dajabón        1020.73          87274          86
# 4  Distrito Nacional  Santo Domingo         104.44        1402749       13431
#   ADM0_PCODE                 ADM2_ES                        ADM2_REF.1  \
# 0         DO                  Duarte                  Provincia Duarte
# 1         DO        Hermanas Mirabal        Provincia Hermanas Mirabal
# 2         DO  María Trinidad Sánchez  Provincia Maria Trinidad Sanchez
# 3         DO                  Samaná                  Provincia Samana
# 4         DO                 Dajabón                 Provincia Dajabon
#
#                                         address        lat        lon
# 0                  Duarte, República Dominicana  19.243456 -70.087743
# 1        Hermanas Mirabal, República Dominicana  19.408967 -70.392841
# 2  María Trinidad Sánchez, República Dominicana  19.444598 -69.984468
# 3                  Samaná, República Dominicana  19.264811 -69.493002
# 4                 Dajabón, República Dominicana  19.458693 -71.602296

# %%
df_4.rename(columns={'ADM0_PCODE':'adm0code', 'ADM2_ES':'Province'}, inplace = True)
df_dom = dom1.merge(df_4, on='Province', how='right')
df_dom.head()
# Out:
# C:\Users\dadyf\Anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#             Province        Capital  Area (km²)[5]  Population[4]  Density[5]  \
# 0               Azua           Azua        2531.77         298246         118
# 1            Baoruco          Neiba        1282.23         111269          87
# 2           Barahona       Barahona        1739.38         232818         134
# 3            Dajabón        Dajabón        1020.73          87274          86
# 4  Distrito Nacional  Santo Domingo         104.44        1402749       13431
#
#   adm0code          ADM2_REF.1                                  address  \
# 0       DO      Provincia Azua               Azua, República Dominicana
# 1       DO   Provincia Baoruco            Baoruco, República Dominicana
# 2       DO  Provincia Barahona           Barahona, República Dominicana
# 3       DO   Provincia Dajabon            Dajabón, República Dominicana
# 4       DO   Distrito Nacional  Distrito Nacional, República Dominicana
#
#          lat        lon
# 0  18.576793 -70.833477
# 1  18.489458 -71.330847
# 2  18.171481 -71.209530
# 3  19.458693 -71.602296
# 4  18.485258 -69.929908

# %%
df_dom.columns.to_list()
# Out:
# ['Province',
#  'Capital',
#  'Area (km²)[5]',
#  'Population[4]',
#  'Density[5]',
#  'adm0code',
#  'ADM2_REF.1',
#  'address',
#  'lat',
#  'lon']

# %%
df_dom = df_dom[['adm0code',
 'Province',
 'ADM2_REF.1',
 'Capital',
 'Area (km²)[5]',
 'Population[4]',
 'Density[5]',
 'address',
 'lat',
 'lon']]

df_dom.head()
# Out:
#   adm0code           Province          ADM2_REF.1        Capital  \
# 0       DO               Azua      Provincia Azua           Azua
# 1       DO            Baoruco   Provincia Baoruco          Neiba
# 2       DO           Barahona  Provincia Barahona       Barahona
# 3       DO            Dajabón   Provincia Dajabon        Dajabón
# 4       DO  Distrito Nacional   Distrito Nacional  Santo Domingo
#
#    Area (km²)[5]  Population[4]  Density[5]  \
# 0        2531.77         298246         118
# 1        1282.23         111269          87
# 2        1739.38         232818         134
# 3        1020.73          87274          86
# 4         104.44        1402749       13431
#
#                                    address        lat        lon
# 0               Azua, República Dominicana  18.576793 -70.833477
# 1            Baoruco, República Dominicana  18.489458 -71.330847
# 2           Barahona, República Dominicana  18.171481 -71.209530
# 3            Dajabón, República Dominicana  19.458693 -71.602296
# 4  Distrito Nacional, República Dominicana  18.485258 -69.929908

# %%
import requests
import json

url = "https://dr-covid-19-tracker.p.rapidapi.com/provinces"

headers = {
    'x-rapidapi-host': "dr-covid-19-tracker.p.rapidapi.com",
    'x-rapidapi-key': "ade64d90cbmshdd1da1274dfdcfdp11cb27jsn0f762048d1e8"
    }

response = requests.request("GET", url, headers=headers)

result = response.json()

# %%
result = response.json()
result[0]
# Out:
# {'country': [{'code': 'DOM',
#    'name': 'Dominican Republic',
#    'total_confirmed': 4680,
#    'total_recovered': 363,
#    'total_deaths': 226,
#    'tests': 15583}]}

# %%
result[1].keys()
# Out:
# dict_keys(['provinces'])

# %%
result[1]['provinces'][0]
# Out:
# {'iso': '01',
#  'name': 'Distrito Nacional',
#  'code': 'DN',
#  'country': 'Dominican Republic',
#  'confirmed': 1198,
#  'recovered': 191,
#  'deaths': 30}

# %%
name, confirmed , recovered, deaths = [],[],[],[]

for res in result[1]['provinces']:
    name.append(res['name'])
    confirmed.append(res['confirmed'])
    recovered.append(res['recovered'])
    deaths.append(res['deaths'])
    
covid_dom = pd.DataFrame({'Province':name, 'confirmed':confirmed, 'recovered':recovered, 'deaths':deaths})
covid_dom.head()
# Out:
#             Province  confirmed  recovered  deaths
# 0  Distrito Nacional       1198        191      30
# 1               Azua         22          1       1
# 2           Bahoruco          4          1       0
# 3           Barahona         25          1       1
# 4            Dajabón          1          0       0

# %%
covid_dom.shape
# Out:
# (32, 4)

# %%
is_diff(covid_dom['Province'], df_dom['Province'])
# Out:
# {'Elias Piña', 'Bahoruco'}

# %%
covid_dom['Province'] = covid_dom['Province'].replace(['Bahoruco', 'Elias Piña' ], ['Baoruco', 'Elías Piña'])

# %%
covid_dom['Province'].unique()
# Out:
# array(['Distrito Nacional', 'Azua', 'Baoruco', 'Barahona', 'Dajabón',
#        'Duarte', 'Elías Piña', 'El Seibo', 'Espaillat', 'Independencia',
#        'La Altagracia', 'La Romana', 'La Vega', 'María Trinidad Sánchez',
#        'Monte Cristi', 'Pedernales', 'Peravia', 'Puerto Plata',
#        'Hermanas Mirabal', 'Samaná', 'San Cristóbal', 'San Juan',
#        'San Pedro de Macorís', 'Sánchez Ramírez', 'Santiago',
#        'Santiago Rodríguez', 'Valverde', 'Monseñor Nouel', 'Monte Plata',
#        'Hato Mayor', 'San José de Ocoa', 'Santo Domingo'], dtype=object)

# %%
df_dom_final = df_dom.merge(covid_dom, on = 'Province', how = 'left')
df_dom_final.head()
# Out:
#   adm0code           Province          ADM2_REF.1        Capital  \
# 0       DO               Azua      Provincia Azua           Azua
# 1       DO            Baoruco   Provincia Baoruco          Neiba
# 2       DO           Barahona  Provincia Barahona       Barahona
# 3       DO            Dajabón   Provincia Dajabon        Dajabón
# 4       DO  Distrito Nacional   Distrito Nacional  Santo Domingo
#
#    Area (km²)[5]  Population[4]  Density[5]  \
# 0        2531.77         298246         118
# 1        1282.23         111269          87
# 2        1739.38         232818         134
# 3        1020.73          87274          86
# 4         104.44        1402749       13431
#
#                                    address        lat        lon  confirmed  \
# 0               Azua, República Dominicana  18.576793 -70.833477         22
# 1            Baoruco, República Dominicana  18.489458 -71.330847          4
# 2           Barahona, República Dominicana  18.171481 -71.209530         25
# 3            Dajabón, República Dominicana  19.458693 -71.602296          1
# 4  Distrito Nacional, República Dominicana  18.485258 -69.929908       1198
#
#    recovered  deaths
# 0          1       1
# 1          1       0
# 2          1       1
# 3          0       0
# 4        191      30

# %%
df_dom_final.shape
# Out:
# (32, 13)

# %%
df_ht.to_csv(r'../output/cleaned/df_ht.csv', index = False)
df_ht.head()
# Out:
#    Département Chef-Lieu ou Capitale  Superficie (km²) adm0code  Population  \
# 0   Artibonite          Les Gonaïves              4984       HT     2047152
# 1       Centre                Hinche              3675       HT      845594
# 2  Grande'Anse               Jérémie              1871       HT      481065
# 3       Nippes             Miragoâne              1268       HT      351593
# 4         Nord           Cap-Haïtien              2106       HT     1159761
#
#    Density/km²                                            address        lat  \
# 0          412  Les Gonaïves, Arrondissement des Gonaïves, Dép...  19.446060
# 1          231  Hinche, Arrondissement de Hinche, Département ...  19.144554
# 2          258  Jérémie, Arrondissement de Jérémie, Départemen...  18.644583
# 3          278  Miragoâne, Arrondissement de Miragoâne, Départ...  18.444843
# 4          552  Cap-Haïtien, Arrondissement de Cap-Haïtien, Dé...  19.759524
#
#          lon
# 0 -72.688434
# 1 -72.008753
# 2 -74.113918
# 3 -73.088639
# 4 -72.200807

# %%
df_dom_final.to_csv(r'../output/cleaned/df_dom.csv', index = False)
df_dom_final.head()
# Out:
#   adm0code           Province          ADM2_REF.1        Capital  \
# 0       DO               Azua      Provincia Azua           Azua
# 1       DO            Baoruco   Provincia Baoruco          Neiba
# 2       DO           Barahona  Provincia Barahona       Barahona
# 3       DO            Dajabón   Provincia Dajabon        Dajabón
# 4       DO  Distrito Nacional   Distrito Nacional  Santo Domingo
#
#    Area (km²)[5]  Population[4]  Density[5]  \
# 0        2531.77         298246         118
# 1        1282.23         111269          87
# 2        1739.38         232818         134
# 3        1020.73          87274          86
# 4         104.44        1402749       13431
#
#                                    address        lat        lon  confirmed  \
# 0               Azua, República Dominicana  18.576793 -70.833477         22
# 1            Baoruco, República Dominicana  18.489458 -71.330847          4
# 2           Barahona, República Dominicana  18.171481 -71.209530         25
# 3            Dajabón, República Dominicana  19.458693 -71.602296          1
# 4  Distrito Nacional, República Dominicana  18.485258 -69.929908       1198
#
#    recovered  deaths
# 0          1       1
# 1          1       0
# 2          1       1
# 3          0       0
# 4        191      30
